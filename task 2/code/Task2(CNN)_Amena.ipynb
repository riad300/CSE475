# %%
# ===============================
# CSE475 (Fall 2025) - Task 1: EDA
# Dataset: Betel Leaf Dataset (btdym2t6mt/1)
# Author: <Your Name>
# ===============================

import os, cv2, numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from tqdm import tqdm
from PIL import Image
import imagehash
from sklearn.model_selection import train_test_split
import albumentations as A
from albumentations.pytorch import ToTensorV2

# ---- CONFIG ----
base_path = "/kaggle/input/betel-leaf-dataset/Controlled Environment"  # change if different
classes = os.listdir(base_path)
print("Classes found:", classes)

# ===============================
# 1. Load basic dataset info
# ===============================
data = []
for cls in classes:
    folder = os.path.join(base_path, cls)
    for f in os.listdir(folder):
        path = os.path.join(folder, f)
        img = cv2.imread(path)
        if img is not None:
            h, w, c = img.shape
            data.append([path, cls, h, w])

df = pd.DataFrame(data, columns=["path", "class", "height", "width"])
print("\nSample entries:")
print(df.head())
print("\nClass distribution:")
print(df["class"].value_counts())

# ===============================
# 2. Resolution and Aspect Ratio
# ===============================
df["aspect_ratio"] = df["width"] / df["height"]
plt.figure(figsize=(8,5))
sns.histplot(df["aspect_ratio"], bins=30)
plt.title("Aspect Ratio Distribution")
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(x="class", y="height", data=df)
plt.title("Image Height Distribution per Class")
plt.show()

# ===============================
# 3. RGB & HSV Statistics
# ===============================
def color_stats(img):
    stats = {}
    for i, ch in enumerate(["R","G","B"]):
        stats[ch+"_mean"] = np.mean(img[:,:,i])
        stats[ch+"_std"] = np.std(img[:,:,i])
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    stats["H_mean"] = np.mean(hsv[:,:,0])
    stats["S_mean"] = np.mean(hsv[:,:,1])
    stats["V_mean"] = np.mean(hsv[:,:,2])
    return stats

subset = df.sample(20, random_state=42)
rgb_stats = []
for p in tqdm(subset["path"], desc="Computing RGB/HSV stats"):
    img = cv2.imread(p)
    rgb_stats.append(color_stats(img))
rgb_df = pd.DataFrame(rgb_stats)
print("\nRGB/HSV mean/std summary:")
print(rgb_df.describe())

# Plot RGB hist for one random sample
sample_img = cv2.imread(subset.iloc[0]["path"])
colors = ('b','g','r')
plt.figure(figsize=(8,5))
for i,col in enumerate(colors):
    histr = cv2.calcHist([sample_img],[i],None,[256],[0,256])
    plt.plot(histr, color=col)
plt.title("RGB Histogram Example")
plt.show()

# ===============================
# 4. Brightness/Contrast Spread
# ===============================
def brightness_contrast(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray.mean(), gray.std()

br_ct = []
for p in tqdm(subset["path"], desc="Brightness/Contrast"):
    img = cv2.imread(p)
    br_ct.append(brightness_contrast(img))
br_ct = np.array(br_ct)
print("\nBrightness mean/std (subset):", br_ct.mean(axis=0))

# ===============================
# 5. Sharpness/Noise Proxy (Laplacian)
# ===============================
def sharpness(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return cv2.Laplacian(gray, cv2.CV_64F).var()

df["sharpness"] = [sharpness(cv2.imread(p)) for p in tqdm(df["path"], desc="Sharpness")]
plt.figure(figsize=(8,5))
sns.boxplot(x="class", y="sharpness", data=df)
plt.title("Sharpness by Class")
plt.show()

# ===============================
# 6. White Balance (Gray-World)
# ===============================
means = []
for p in tqdm(subset["path"], desc="Gray-World Check"):
    img = cv2.imread(p)
    means.append(np.mean(img, axis=(0,1)))
means = np.array(means)
print("\nChannel means (BGR):", means.mean(axis=0))

# ===============================
# 7. Duplicate Detection (Perceptual Hash)
# ===============================
hashes = {}
dupes = []
for p in tqdm(df["path"], desc="Checking duplicates"):
    try:
        h = imagehash.phash(Image.open(p))
        if h in hashes:
            dupes.append((p, hashes[h]))
        else:
            hashes[h] = p
    except:
        pass

print(f"\nFound {len(dupes)} potential duplicates.")
if dupes:
    for d in dupes[:5]:
        print("Duplicate pair:", d)

# ===============================
# 8. Class Balance Plot
# ===============================
plt.figure(figsize=(6,4))
sns.countplot(x="class", data=df)
plt.title("Class Balance")
plt.show()

# ===============================
# 9. Train-Test Split (Leakage Safeguard)
# ===============================
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df["class"], random_state=42)
print(f"\nTrain: {len(train_df)} | Test: {len(test_df)}")

# ===============================
# 10. Augmentation Probe
# ===============================
transform = A.Compose([
    A.RandomCrop(height=200, width=200),
    A.HorizontalFlip(p=0.5),
    A.ColorJitter(p=0.5),
    A.GaussianBlur(p=0.3),
    ToTensorV2()
])

sample_paths = list(subset["path"].values)[:3]
for p in sample_paths:
    img = cv2.cvtColor(cv2.imread(p), cv2.COLOR_BGR2RGB)
    augmented = transform(image=img)["image"].permute(1,2,0).numpy()
    plt.figure(figsize=(8,4))
    plt.subplot(1,2,1); plt.imshow(img); plt.title("Original")
    plt.subplot(1,2,2); plt.imshow(augmented); plt.title("Augmented")
    plt.show()

print("\n✅ EDA complete — all key outputs displayed.")
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/check_version.py:147: UserWarning: Error fetching version info <urlopen error [Errno -3] Temporary failure in name resolution>
#   data = fetch_version_info()
# Classes found: ['Diseased', 'Dried', 'Healthy']
# Sample entries:
#                                                 path     class  height  width
# 0  /kaggle/input/betel-leaf-dataset/Controlled En...  Diseased    6112   6112
# 1  /kaggle/input/betel-leaf-dataset/Controlled En...  Diseased    6112   6112
# 2  /kaggle/input/betel-leaf-dataset/Controlled En...  Diseased    6112   6112
# 3  /kaggle/input/betel-leaf-dataset/Controlled En...  Diseased    6112   6112
# 4  /kaggle/input/betel-leaf-dataset/Controlled En...  Diseased    6112   6112
#
# Class distribution:
# class
# Dried       340
# Healthy     333
# Diseased    220
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Computing RGB/HSV stats:   0%|          | 0/20 [00:00<?, ?it/s]
# Computing RGB/HSV stats:   5%|▌         | 1/20 [00:01<00:23,  1.23s/it]
# Computing RGB/HSV stats:  10%|█         | 2/20 [00:02<00:22,  1.25s/it]
# Computing RGB/HSV stats:  15%|█▌        | 3/20 [00:03<00:21,  1.26s/it]
# Computing RGB/HSV stats:  20%|██        | 4/20 [00:04<00:19,  1.24s/it]
# Computing RGB/HSV stats:  25%|██▌       | 5/20 [00:06<00:18,  1.23s/it]
# Computing RGB/HSV stats:  30%|███       | 6/20 [00:07<00:17,  1.23s/it]
# Computing RGB/HSV stats:  35%|███▌      | 7/20 [00:08<00:16,  1.24s/it]
# Computing RGB/HSV stats:  40%|████      | 8/20 [00:09<00:14,  1.22s/it]
# Computing RGB/HSV stats:  45%|████▌     | 9/20 [00:11<00:13,  1.23s/it]
# Computing RGB/HSV stats:  50%|█████     | 10/20 [00:12<00:12,  1.22s/it]
# Computing RGB/HSV stats:  55%|█████▌    | 11/20 [00:13<00:10,  1.22s/it]
# Computing RGB/HSV stats:  60%|██████    | 12/20 [00:14<00:09,  1.21s/it]
# Computing RGB/HSV stats:  65%|██████▌   | 13/20 [00:15<00:08,  1.22s/it]
# Computing RGB/HSV stats:  70%|███████   | 14/20 [00:17<00:07,  1.23s/it]
# Computing RGB/HSV stats:  75%|███████▌  | 15/20 [00:18<00:06,  1.22s/it]
# Computing RGB/HSV stats:  80%|████████  | 16/20 [00:19<00:04,  1.23s/it]
# Computing RGB/HSV stats:  85%|████████▌ | 17/20 [00:20<00:03,  1.23s/it]
# Computing RGB/HSV stats:  90%|█████████ | 18/20 [00:22<00:02,  1.24s/it]
# Computing RGB/HSV stats:  95%|█████████▌| 19/20 [00:23<00:01,  1.20s/it]
# Computing RGB/HSV stats: 100%|██████████| 20/20 [00:24<00:00,  1.21s/it]
# Computing RGB/HSV stats: 100%|██████████| 20/20 [00:24<00:00,  1.22s/it]
# RGB/HSV mean/std summary:
#            R_mean      R_std      G_mean      G_std      B_mean      B_std  \
# count   20.000000  20.000000   20.000000  20.000000   20.000000  20.000000
# mean   158.223602  60.500712  166.787008  37.458642  163.011909  41.771130
# std      8.296913   7.185983    7.285863  11.869491    7.006443   8.167971
# min    142.968054  43.435114  145.645051  17.860924  145.667454  24.750282
# 25%    153.833568  56.442079  163.837845  29.761833  159.615000  39.147868
# 50%    158.466304  60.596207  167.415784  34.063269  162.417403  40.962408
# 75%    160.476589  64.240123  172.632145  46.514551  166.925191  46.126167
# max    173.622374  73.600806  176.920709  59.265041  174.220334  56.912105
#
#            H_mean     S_mean      V_mean
# count   20.000000  20.000000   20.000000
# mean    93.792637  35.354346  170.203615
# std      6.839521   9.252077    6.698205
# min     74.255337  17.503272  150.926033
# 25%     91.032063  30.047899  165.949832
# 50%     95.485643  34.792522  169.476943
# 75%     98.350364  39.733297  174.764586
# max    103.291661  54.740038  179.747114
# Brightness/Contrast:   0%|          | 0/20 [00:00<?, ?it/s]
# Brightness/Contrast:   5%|▌         | 1/20 [00:00<00:10,  1.83it/s]
# Brightness/Contrast:  10%|█         | 2/20 [00:01<00:10,  1.76it/s]
# Brightness/Contrast:  15%|█▌        | 3/20 [00:01<00:09,  1.78it/s]
# Brightness/Contrast:  20%|██        | 4/20 [00:02<00:08,  1.79it/s]
# Brightness/Contrast:  25%|██▌       | 5/20 [00:02<00:08,  1.81it/s]
# Brightness/Contrast:  30%|███       | 6/20 [00:03<00:07,  1.82it/s]
# Brightness/Contrast:  35%|███▌      | 7/20 [00:03<00:07,  1.77it/s]
# Brightness/Contrast:  40%|████      | 8/20 [00:04<00:06,  1.79it/s]
# Brightness/Contrast:  45%|████▌     | 9/20 [00:05<00:06,  1.79it/s]
# Brightness/Contrast:  50%|█████     | 10/20 [00:05<00:05,  1.80it/s]
# Brightness/Contrast:  55%|█████▌    | 11/20 [00:06<00:04,  1.80it/s]
# Brightness/Contrast:  60%|██████    | 12/20 [00:06<00:04,  1.82it/s]
# Brightness/Contrast:  65%|██████▌   | 13/20 [00:07<00:03,  1.78it/s]
# Brightness/Contrast:  70%|███████   | 14/20 [00:07<00:03,  1.75it/s]
# Brightness/Contrast:  75%|███████▌  | 15/20 [00:08<00:02,  1.75it/s]
# Brightness/Contrast:  80%|████████  | 16/20 [00:08<00:02,  1.74it/s]
# Brightness/Contrast:  85%|████████▌ | 17/20 [00:09<00:01,  1.77it/s]
# Brightness/Contrast:  90%|█████████ | 18/20 [00:10<00:01,  1.75it/s]
# Brightness/Contrast:  95%|█████████▌| 19/20 [00:10<00:00,  1.87it/s]
# Brightness/Contrast: 100%|██████████| 20/20 [00:11<00:00,  1.85it/s]
# Brightness/Contrast: 100%|██████████| 20/20 [00:11<00:00,  1.80it/s]
# Brightness mean/std (subset): [164.65112204  41.22281756]
# Sharpness:   0%|          | 0/893 [00:00<?, ?it/s]
# Sharpness:   0%|          | 1/893 [00:00<09:27,  1.57it/s]
# Sharpness:   0%|          | 2/893 [00:01<09:16,  1.60it/s]
# Sharpness:   0%|          | 3/893 [00:01<09:21,  1.59it/s]
# Sharpness:   0%|          | 4/893 [00:02<09:34,  1.55it/s]
# Sharpness:   1%|          | 5/893 [00:03<09:26,  1.57it/s]
# Sharpness:   1%|          | 6/893 [00:03<09:22,  1.58it/s]
# Sharpness:   1%|          | 7/893 [00:04<09:20,  1.58it/s]
# Sharpness:   1%|          | 8/893 [00:05<09:28,  1.56it/s]
# Sharpness:   1%|          | 9/893 [00:05<09:24,  1.57it/s]
# Sharpness:   1%|          | 10/893 [00:06<09:22,  1.57it/s]
# Sharpness:   1%|          | 11/893 [00:07<09:22,  1.57it/s]
# Sharpness:   1%|▏         | 12/893 [00:07<09:37,  1.53it/s]
# Sharpness:   1%|▏         | 13/893 [00:08<09:30,  1.54it/s]
# Sharpness:   2%|▏         | 14/893 [00:08<09:25,  1.55it/s]
# Sharpness:   2%|▏         | 15/893 [00:09<09:19,  1.57it/s]
# Sharpness:   2%|▏         | 16/893 [00:10<09:16,  1.57it/s]
# Sharpness:   2%|▏         | 17/893 [00:10<09:18,  1.57it/s]
# Sharpness:   2%|▏         | 18/893 [00:11<09:13,  1.58it/s]
# Sharpness:   2%|▏         | 19/893 [00:12<09:13,  1.58it/s]
# Sharpness:   2%|▏         | 20/893 [00:12<09:12,  1.58it/s]
# Sharpness:   2%|▏         | 21/893 [00:13<09:15,  1.57it/s]
# Sharpness:   2%|▏         | 22/893 [00:14<09:12,  1.58it/s]
# Sharpness:   3%|▎         | 23/893 [00:14<09:20,  1.55it/s]
# Sharpness:   3%|▎         | 24/893 [00:15<09:13,  1.57it/s]
# Sharpness:   3%|▎         | 25/893 [00:15<09:08,  1.58it/s]
# Sharpness:   3%|▎         | 26/893 [00:16<09:06,  1.59it/s]
# Checking duplicates:  80%|████████  | 717/893 [05:37<01:22,  2.12it/s]
# Checking duplicates:  80%|████████  | 718/893 [05:38<01:21,  2.14it/s]
# Checking duplicates:  81%|████████  | 719/893 [05:38<01:21,  2.13it/s]
# Checking duplicates:  81%|████████  | 720/893 [05:38<01:20,  2.15it/s]
# Checking duplicates:  81%|████████  | 721/893 [05:39<01:19,  2.17it/s]
# Checking duplicates:  81%|████████  | 722/893 [05:39<01:19,  2.15it/s]
# Checking duplicates:  81%|████████  | 723/893 [05:40<01:18,  2.17it/s]
# Checking duplicates:  81%|████████  | 724/893 [05:40<01:18,  2.16it/s]
# Checking duplicates:  81%|████████  | 725/893 [05:41<01:17,  2.18it/s]
# Checking duplicates:  81%|████████▏ | 726/893 [05:41<01:18,  2.14it/s]
# Checking duplicates:  81%|████████▏ | 727/893 [05:42<01:17,  2.15it/s]
# Checking duplicates:  82%|████████▏ | 728/893 [05:42<01:16,  2.15it/s]
# Checking duplicates:  82%|████████▏ | 729/893 [05:43<01:17,  2.12it/s]
# Checking duplicates:  82%|████████▏ | 730/893 [05:43<01:16,  2.13it/s]
# Checking duplicates:  82%|████████▏ | 731/893 [05:44<01:15,  2.14it/s]
# Checking duplicates:  82%|████████▏ | 732/893 [05:44<01:14,  2.16it/s]
# Checking duplicates:  82%|████████▏ | 733/893 [05:44<01:13,  2.17it/s]
# Checking duplicates:  82%|████████▏ | 734/893 [05:45<01:13,  2.16it/s]
# Checking duplicates:  82%|████████▏ | 735/893 [05:45<01:13,  2.16it/s]
# Checking duplicates:  82%|████████▏ | 736/893 [05:46<01:13,  2.15it/s]
# Checking duplicates:  83%|████████▎ | 737/893 [05:46<01:11,  2.17it/s]
# Checking duplicates:  83%|████████▎ | 738/893 [05:47<01:10,  2.18it/s]
# Checking duplicates:  83%|████████▎ | 739/893 [05:47<01:11,  2.17it/s]
# Checking duplicates:  83%|████████▎ | 740/893 [05:48<01:12,  2.11it/s]
# Checking duplicates:  83%|████████▎ | 741/893 [05:48<01:13,  2.08it/s]
# Checking duplicates:  83%|████████▎ | 742/893 [05:49<01:11,  2.12it/s]
# Checking duplicates:  83%|████████▎ | 743/893 [05:49<01:09,  2.14it/s]
# Checking duplicates:  83%|████████▎ | 744/893 [05:50<01:09,  2.14it/s]
# Checking duplicates:  83%|████████▎ | 745/893 [05:50<01:08,  2.16it/s]
# Checking duplicates:  84%|████████▎ | 746/893 [05:51<01:07,  2.17it/s]
# Checking duplicates:  84%|████████▎ | 747/893 [05:51<01:07,  2.18it/s]
# Checking duplicates:  84%|████████▍ | 748/893 [05:51<01:06,  2.17it/s]
# Checking duplicates:  84%|████████▍ | 749/893 [05:52<01:06,  2.18it/s]
# Checking duplicates:  84%|████████▍ | 750/893 [05:52<01:05,  2.19it/s]
# Checking duplicates:  84%|████████▍ | 751/893 [05:53<01:05,  2.18it/s]
# Checking duplicates:  84%|████████▍ | 752/893 [05:53<01:04,  2.18it/s]
# Checking duplicates:  84%|████████▍ | 753/893 [05:54<01:04,  2.18it/s]
# Checking duplicates:  89%|████████▊ | 791/893 [06:12<00:46,  2.17it/s]
# Checking duplicates:  89%|████████▊ | 792/893 [06:12<00:46,  2.18it/s]
# Checking duplicates:  89%|████████▉ | 793/893 [06:13<00:45,  2.19it/s]
# Checking duplicates:  89%|████████▉ | 794/893 [06:13<00:45,  2.20it/s]
# Checking duplicates:  89%|████████▉ | 795/893 [06:14<00:44,  2.18it/s]
# Checking duplicates:  89%|████████▉ | 796/893 [06:14<00:44,  2.16it/s]
# Checking duplicates:  89%|████████▉ | 797/893 [06:14<00:44,  2.14it/s]
# Checking duplicates:  89%|████████▉ | 798/893 [06:15<00:44,  2.13it/s]
# Checking duplicates:  89%|████████▉ | 799/893 [06:15<00:43,  2.15it/s]
# Checking duplicates:  90%|████████▉ | 800/893 [06:16<00:43,  2.15it/s]
# Checking duplicates:  90%|████████▉ | 801/893 [06:16<00:42,  2.18it/s]
# Checking duplicates:  90%|████████▉ | 802/893 [06:17<00:41,  2.18it/s]
# Checking duplicates:  90%|████████▉ | 803/893 [06:17<00:42,  2.13it/s]
# Checking duplicates:  90%|█████████ | 804/893 [06:18<00:41,  2.14it/s]
# Checking duplicates:  90%|█████████ | 805/893 [06:18<00:41,  2.15it/s]
# Checking duplicates:  90%|█████████ | 806/893 [06:19<00:40,  2.15it/s]
# Checking duplicates:  90%|█████████ | 807/893 [06:19<00:39,  2.16it/s]
# Checking duplicates:  90%|█████████ | 808/893 [06:20<00:40,  2.09it/s]
# Checking duplicates:  91%|█████████ | 809/893 [06:20<00:39,  2.12it/s]
# Checking duplicates:  91%|█████████ | 810/893 [06:21<00:38,  2.15it/s]
# Checking duplicates:  91%|█████████ | 811/893 [06:21<00:37,  2.18it/s]
# Checking duplicates:  91%|█████████ | 812/893 [06:21<00:37,  2.15it/s]
# Checking duplicates:  91%|█████████ | 813/893 [06:22<00:36,  2.20it/s]
# Checking duplicates:  91%|█████████ | 814/893 [06:22<00:35,  2.23it/s]
# Checking duplicates:  91%|█████████▏| 815/893 [06:23<00:35,  2.20it/s]
# Checking duplicates:  91%|█████████▏| 816/893 [06:23<00:35,  2.18it/s]
# Checking duplicates:  91%|█████████▏| 817/893 [06:24<00:35,  2.13it/s]
# Checking duplicates:  92%|█████████▏| 818/893 [06:24<00:34,  2.15it/s]
# Checking duplicates:  92%|█████████▏| 819/893 [06:25<00:33,  2.18it/s]
# Checking duplicates:  92%|█████████▏| 820/893 [06:25<00:33,  2.18it/s]
# Checking duplicates:  92%|█████████▏| 821/893 [06:26<00:33,  2.18it/s]
# Checking duplicates:  92%|█████████▏| 822/893 [06:26<00:33,  2.14it/s]
# Checking duplicates:  92%|█████████▏| 823/893 [06:26<00:32,  2.15it/s]
# Checking duplicates:  92%|█████████▏| 824/893 [06:27<00:32,  2.13it/s]
# Checking duplicates:  92%|█████████▏| 825/893 [06:27<00:31,  2.14it/s]
# Checking duplicates:  92%|█████████▏| 826/893 [06:28<00:31,  2.13it/s]
# Checking duplicates:  93%|█████████▎| 827/893 [06:28<00:31,  2.13it/s]
# Checking duplicates:  93%|█████████▎| 828/893 [06:29<00:30,  2.12it/s]
# Checking duplicates:  93%|█████████▎| 829/893 [06:29<00:29,  2.14it/s]
# Checking duplicates:  93%|█████████▎| 830/893 [06:30<00:29,  2.14it/s]
# Checking duplicates:  93%|█████████▎| 831/893 [06:30<00:28,  2.17it/s]
# Checking duplicates:  93%|█████████▎| 832/893 [06:31<00:28,  2.18it/s]
# Checking duplicates:  93%|█████████▎| 833/893 [06:31<00:27,  2.17it/s]
# Checking duplicates:  93%|█████████▎| 834/893 [06:32<00:27,  2.18it/s]
# Checking duplicates:  94%|█████████▎| 835/893 [06:32<00:26,  2.16it/s]
# Checking duplicates:  94%|█████████▎| 836/893 [06:33<00:26,  2.18it/s]
# Checking duplicates:  94%|█████████▎| 837/893 [06:33<00:25,  2.18it/s]
# Checking duplicates:  94%|█████████▍| 838/893 [06:33<00:25,  2.18it/s]
# Checking duplicates:  94%|█████████▍| 839/893 [06:34<00:25,  2.16it/s]
# Checking duplicates:  94%|█████████▍| 840/893 [06:34<00:24,  2.16it/s]
# Checking duplicates:  94%|█████████▍| 841/893 [06:35<00:24,  2.15it/s]
# Checking duplicates:  94%|█████████▍| 842/893 [06:35<00:23,  2.14it/s]
# Checking duplicates:  94%|█████████▍| 843/893 [06:36<00:23,  2.15it/s]
# Checking duplicates:  95%|█████████▍| 844/893 [06:36<00:22,  2.15it/s]
# Checking duplicates:  95%|█████████▍| 845/893 [06:37<00:21,  2.18it/s]
# Checking duplicates:  95%|█████████▍| 846/893 [06:37<00:21,  2.14it/s]
# Checking duplicates:  95%|█████████▍| 847/893 [06:38<00:21,  2.15it/s]
# Checking duplicates:  95%|█████████▍| 848/893 [06:38<00:20,  2.15it/s]
# Checking duplicates:  95%|█████████▌| 849/893 [06:39<00:20,  2.16it/s]
# Checking duplicates:  95%|█████████▌| 850/893 [06:39<00:19,  2.16it/s]
# Checking duplicates:  95%|█████████▌| 851/893 [06:40<00:19,  2.11it/s]
# Checking duplicates:  95%|█████████▌| 852/893 [06:40<00:19,  2.11it/s]
# Checking duplicates:  96%|█████████▌| 853/893 [06:40<00:18,  2.11it/s]
# Checking duplicates:  96%|█████████▌| 854/893 [06:41<00:18,  2.13it/s]
# Checking duplicates:  96%|█████████▌| 855/893 [06:41<00:17,  2.15it/s]
# Checking duplicates:  96%|█████████▌| 856/893 [06:42<00:17,  2.12it/s]
# Checking duplicates:  96%|█████████▌| 857/893 [06:42<00:16,  2.13it/s]
# Checking duplicates:  96%|█████████▌| 858/893 [06:43<00:17,  2.03it/s]
# Checking duplicates:  96%|█████████▌| 859/893 [06:43<00:16,  2.08it/s]
# Checking duplicates:  96%|█████████▋| 860/893 [06:44<00:15,  2.09it/s]
# Checking duplicates:  96%|█████████▋| 861/893 [06:44<00:15,  2.12it/s]
# Checking duplicates:  97%|█████████▋| 862/893 [06:45<00:14,  2.15it/s]
# Checking duplicates:  97%|█████████▋| 863/893 [06:45<00:13,  2.15it/s]
# Checking duplicates:  97%|█████████▋| 864/893 [06:46<00:13,  2.09it/s]
# Checking duplicates:  97%|█████████▋| 865/893 [06:46<00:13,  2.04it/s]
# Checking duplicates:  97%|█████████▋| 866/893 [06:47<00:12,  2.11it/s]
# Checking duplicates:  97%|█████████▋| 867/893 [06:47<00:12,  2.10it/s]
# Checking duplicates:  97%|█████████▋| 868/893 [06:48<00:11,  2.12it/s]
# Checking duplicates:  97%|█████████▋| 869/893 [06:48<00:11,  2.09it/s]
# Checking duplicates:  97%|█████████▋| 870/893 [06:49<00:10,  2.11it/s]
# Checking duplicates:  98%|█████████▊| 871/893 [06:49<00:10,  2.13it/s]
# Checking duplicates:  98%|█████████▊| 872/893 [06:49<00:09,  2.15it/s]
# Checking duplicates:  98%|█████████▊| 873/893 [06:50<00:09,  2.09it/s]
# Checking duplicates:  98%|█████████▊| 874/893 [06:50<00:08,  2.13it/s]
# Checking duplicates:  98%|█████████▊| 875/893 [06:51<00:08,  2.15it/s]
# Checking duplicates:  98%|█████████▊| 876/893 [06:51<00:07,  2.17it/s]
# Checking duplicates:  98%|█████████▊| 877/893 [06:52<00:07,  2.10it/s]
# Checking duplicates:  98%|█████████▊| 878/893 [06:52<00:07,  2.13it/s]
# Checking duplicates:  98%|█████████▊| 879/893 [06:53<00:06,  2.13it/s]
# Checking duplicates:  99%|█████████▊| 880/893 [06:53<00:06,  2.15it/s]
# Checking duplicates:  99%|█████████▊| 881/893 [06:54<00:05,  2.14it/s]
# Checking duplicates:  99%|█████████▉| 882/893 [06:54<00:05,  2.12it/s]
# Checking duplicates:  99%|█████████▉| 883/893 [06:55<00:04,  2.13it/s]
# Checking duplicates:  99%|█████████▉| 884/893 [06:55<00:04,  2.14it/s]
# Checking duplicates:  99%|█████████▉| 885/893 [06:56<00:03,  2.17it/s]
# Checking duplicates:  99%|█████████▉| 886/893 [06:56<00:03,  2.20it/s]
# Checking duplicates:  99%|█████████▉| 887/893 [06:56<00:02,  2.21it/s]
# Checking duplicates:  99%|█████████▉| 888/893 [06:57<00:02,  2.20it/s]
# Checking duplicates: 100%|█████████▉| 889/893 [06:57<00:01,  2.19it/s]
# Checking duplicates: 100%|█████████▉| 890/893 [06:58<00:01,  2.17it/s]
# Checking duplicates: 100%|█████████▉| 891/893 [06:58<00:00,  2.12it/s]
# Checking duplicates: 100%|█████████▉| 892/893 [06:59<00:00,  2.10it/s]
# Checking duplicates: 100%|██████████| 893/893 [06:59<00:00,  2.09it/s]
# Checking duplicates: 100%|██████████| 893/893 [06:59<00:00,  2.13it/s]
# Found 3 potential duplicates.
# Duplicate pair: ('/kaggle/input/betel-leaf-dataset/Controlled Environment/Diseased/CE_Diseased_Leaf_040.jpg', '/kaggle/input/betel-leaf-dataset/Controlled Environment/Diseased/CE_Diseased_Leaf_058.jpg')
# Duplicate pair: ('/kaggle/input/betel-leaf-dataset/Controlled Environment/Healthy/CE_Healthy_Leaf_294.jpg', '/kaggle/input/betel-leaf-dataset/Controlled Environment/Healthy/CE_Healthy_Leaf_293.jpg')
# Duplicate pair: ('/kaggle/input/betel-leaf-dataset/Controlled Environment/Healthy/CE_Healthy_Leaf_250.jpg', '/kaggle/input/betel-leaf-dataset/Controlled Environment/Healthy/CE_Healthy_Leaf_330.jpg')
# Train: 714 | Test: 179
# ✅ EDA complete — all key outputs displayed.

# %%
# ==========================
# 2️⃣ Data Transform
# ==========================
from torchvision import datasets, transforms
data_dir = "/kaggle/input/betel-leaf-dataset/Controlled Environment"
image_size = 224
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

dataset = datasets.ImageFolder(root=data_dir, transform=transform)
num_classes = len(dataset.classes)
print(f"✅ Dataset loaded with {len(dataset)} images across {num_classes} classes: {dataset.classes}")
# Out:
# ✅ Dataset loaded with 893 images across 3 classes: ['Diseased', 'Dried', 'Healthy']

# %%
# ==========================================================
# 📘 CSE475 (Fall 2025)
# Task 2: Supervised Baseline (CNN Model)
# Model: Simple CNN
# Dataset: Provided dataset (ImageFolder format)
# 9 Train-Test Ratios × 25 Epochs each
# ==========================================================

import os
import time
import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, random_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import pandas as pd

# ==========================
# 1️⃣ Configuration
# ==========================
data_dir = "/kaggle/input/betel-leaf-dataset/Controlled Environment"   # <-- change this path to your dataset folder
image_size = 224
batch_size = 8
epochs = 25
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

ratios = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]



# ==========================
# 3️⃣ CNN Model Definition
# ==========================
class CNNModel(nn.Module):
    def __init__(self, num_classes):
        super(CNNModel, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * (image_size//4) * (image_size//4), 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        return self.fc(self.conv(x))

# ==========================
# 4️⃣ Training Function
# ==========================
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    train_losses, val_losses = [], []
    for epoch in range(epochs):
        model.train()
        running_loss = 0
        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_losses.append(running_loss / len(train_loader))
        
        # validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                val_loss += criterion(outputs, labels).item()
        val_losses.append(val_loss / len(val_loader))
        print(f"Epoch [{epoch+1}/{epochs}] Train Loss={train_losses[-1]:.4f} | Val Loss={val_losses[-1]:.4f}")
    return train_losses, val_losses

# ==========================
# 5️⃣ Train & Evaluate for 9 Ratios
# ==========================
results = []

for ratio in ratios:
    print(f"\n🚀 Running CNN for Train-Test Split: {int(ratio*100)}:{int((1-ratio)*100)}")
    
    total_size = len(dataset)
    train_size = int(total_size * ratio)
    test_size = total_size - train_size
    
    train_data, test_data = random_split(dataset, [train_size, test_size])
    
    # validation = 10% of train
    val_size = int(train_size * 0.1)
    train_size_adj = train_size - val_size
    train_data, val_data = random_split(train_data, [train_size_adj, val_size])
    
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)
    
    model = CNNModel(num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    start = time.time()
    train_losses, val_losses = train_model(model, train_loader, val_loader, criterion, optimizer, epochs)
    duration = (time.time() - start)/60
    
    # Evaluate
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            outputs = model(imgs)
            preds = torch.argmax(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
    
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
    rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
    cm = confusion_matrix(y_true, y_pred)
    
    print(f"✅ Accuracy: {acc:.3f} | Precision: {prec:.3f} | Recall: {rec:.3f} | F1: {f1:.3f}")
    print(f"⏱ Training Time: {duration:.2f} min")
    print("Confusion Matrix:\n", cm)
    
    # Plot Loss Curve
    plt.figure(figsize=(6,4))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.title(f"Learning Curve ({int(ratio*100)}:{int((1-ratio)*100)})")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    results.append([ratio, acc, prec, rec, f1, duration])

# ==========================
# 6️⃣ Summary Table
# ==========================
df = pd.DataFrame(results, columns=['Train Ratio', 'Accuracy', 'Precision', 'Recall', 'F1-score', 'Train Time (min)'])
display(df.sort_values(by='Accuracy', ascending=False))

print("\n🏁 All 9 ratio experiments completed successfully!")
# Out:
# 🚀 Running CNN for Train-Test Split: 90:9
# Epoch [1/25] Train Loss=0.5305 | Val Loss=0.2909
# Epoch [2/25] Train Loss=0.2946 | Val Loss=0.2193
# Epoch [3/25] Train Loss=0.1901 | Val Loss=0.3173
# Epoch [4/25] Train Loss=0.1753 | Val Loss=0.1896
# Epoch [5/25] Train Loss=0.0778 | Val Loss=0.2009
# Epoch [6/25] Train Loss=0.0566 | Val Loss=0.2636
# Epoch [7/25] Train Loss=0.0960 | Val Loss=0.2199
# Epoch [8/25] Train Loss=0.0632 | Val Loss=0.0913
# Epoch [9/25] Train Loss=0.0837 | Val Loss=0.2202
# Epoch [10/25] Train Loss=0.0206 | Val Loss=0.2468
# Epoch [11/25] Train Loss=0.0090 | Val Loss=0.2631
# Epoch [12/25] Train Loss=0.0050 | Val Loss=0.2638
# Epoch [13/25] Train Loss=0.0025 | Val Loss=0.2653
# Epoch [14/25] Train Loss=0.0014 | Val Loss=0.3049
# Epoch [15/25] Train Loss=0.0014 | Val Loss=0.2889
# Epoch [16/25] Train Loss=0.0007 | Val Loss=0.2766
# Epoch [17/25] Train Loss=0.0003 | Val Loss=0.2981
# Epoch [18/25] Train Loss=0.0008 | Val Loss=0.2904
# Epoch [19/25] Train Loss=0.0007 | Val Loss=0.2917
# Epoch [20/25] Train Loss=0.0009 | Val Loss=0.3467
# Epoch [21/25] Train Loss=0.0349 | Val Loss=0.2779
# Epoch [22/25] Train Loss=0.1182 | Val Loss=0.1401
# Epoch [23/25] Train Loss=0.0970 | Val Loss=0.3173
# Epoch [24/25] Train Loss=0.0356 | Val Loss=0.2765
# Epoch [25/25] Train Loss=0.0147 | Val Loss=0.3259
# ✅ Accuracy: 0.944 | Precision: 0.957 | Recall: 0.931 | F1: 0.939
# ⏱ Training Time: 154.35 min
# Confusion Matrix:
#  [[19  1  4]
#  [ 0 28  0]
#  [ 0  0 38]]
# 🚀 Running CNN for Train-Test Split: 80:19
# Epoch [1/25] Train Loss=0.6599 | Val Loss=0.4334
# Epoch [2/25] Train Loss=0.3216 | Val Loss=0.3387
# Epoch [3/25] Train Loss=0.2255 | Val Loss=0.3708
# Epoch [4/25] Train Loss=0.1689 | Val Loss=0.3467
# Epoch [5/25] Train Loss=0.1267 | Val Loss=0.3505
# Epoch [6/25] Train Loss=0.1218 | Val Loss=0.4672
# Epoch [7/25] Train Loss=0.1047 | Val Loss=0.3108
# Epoch [8/25] Train Loss=0.0660 | Val Loss=0.3128
# Epoch [9/25] Train Loss=0.0801 | Val Loss=0.4475
# Epoch [10/25] Train Loss=0.0565 | Val Loss=0.4621
# Epoch [11/25] Train Loss=0.0344 | Val Loss=0.4424
# Epoch [12/25] Train Loss=0.0534 | Val Loss=0.4613
# Epoch [13/25] Train Loss=0.0150 | Val Loss=0.6317
# Epoch [14/25] Train Loss=0.0124 | Val Loss=0.5689
# Epoch [15/25] Train Loss=0.0040 | Val Loss=0.6595
# Epoch [16/25] Train Loss=0.0016 | Val Loss=0.6266
# Epoch [17/25] Train Loss=0.0008 | Val Loss=0.6273
# Epoch [18/25] Train Loss=0.0050 | Val Loss=0.5995
# Epoch [19/25] Train Loss=0.0156 | Val Loss=0.4400
# Epoch [20/25] Train Loss=0.0907 | Val Loss=0.3990
# Epoch [21/25] Train Loss=0.0143 | Val Loss=0.5995
# Epoch [22/25] Train Loss=0.0161 | Val Loss=0.5124
# Epoch [23/25] Train Loss=0.0666 | Val Loss=0.6665
# Epoch [24/25] Train Loss=0.0070 | Val Loss=0.7920
# Epoch [25/25] Train Loss=0.0043 | Val Loss=0.6889
# ✅ Accuracy: 0.888 | Precision: 0.873 | Recall: 0.867 | F1: 0.869
# ⏱ Training Time: 140.07 min
# Confusion Matrix:
#  [[32  4  8]
#  [ 1 72  0]
#  [ 7  0 55]]
# 🚀 Running CNN for Train-Test Split: 70:30
# Epoch [1/25] Train Loss=0.6103 | Val Loss=0.3084
# Epoch [2/25] Train Loss=0.3437 | Val Loss=0.3568
# Epoch [3/25] Train Loss=0.2546 | Val Loss=0.3744
# Epoch [4/25] Train Loss=0.1737 | Val Loss=0.2750
# Epoch [5/25] Train Loss=0.1470 | Val Loss=0.4376
# Epoch [6/25] Train Loss=0.1556 | Val Loss=0.4771
# Epoch [7/25] Train Loss=0.2259 | Val Loss=0.2329
# Epoch [8/25] Train Loss=0.1014 | Val Loss=0.9903
# Epoch [9/25] Train Loss=0.0896 | Val Loss=0.6014
# Epoch [10/25] Train Loss=0.0606 | Val Loss=0.7169
# Epoch [11/25] Train Loss=0.0625 | Val Loss=0.4205
# Epoch [12/25] Train Loss=0.0430 | Val Loss=1.8480
# Epoch [13/25] Train Loss=0.1080 | Val Loss=0.4255
# Epoch [14/25] Train Loss=0.1136 | Val Loss=0.3645
# Epoch [15/25] Train Loss=0.0637 | Val Loss=0.8576
# Epoch [16/25] Train Loss=0.0211 | Val Loss=1.1317
# Epoch [17/25] Train Loss=0.0288 | Val Loss=0.7391
# Epoch [18/25] Train Loss=0.0156 | Val Loss=1.2757
# Epoch [19/25] Train Loss=0.0125 | Val Loss=0.3136
# Epoch [20/25] Train Loss=0.0211 | Val Loss=1.3304
# Epoch [21/25] Train Loss=0.0058 | Val Loss=1.3234
# Epoch [22/25] Train Loss=0.0030 | Val Loss=0.6804
# Epoch [23/25] Train Loss=0.0023 | Val Loss=0.9350
# Epoch [24/25] Train Loss=0.0035 | Val Loss=0.9436
# Epoch [25/25] Train Loss=0.0016 | Val Loss=1.0731
# ✅ Accuracy: 0.918 | Precision: 0.908 | Recall: 0.906 | F1: 0.907
# ⏱ Training Time: 127.54 min
# Confusion Matrix:
#  [[ 54   7   4]
#  [  1 105   0]
#  [ 10   0  87]]
# 🚀 Running CNN for Train-Test Split: 60:40
# Epoch [1/25] Train Loss=0.8240 | Val Loss=0.3277
# Epoch [2/25] Train Loss=0.3217 | Val Loss=0.2824
# Epoch [3/25] Train Loss=0.2220 | Val Loss=0.2642
# Epoch [4/25] Train Loss=0.1724 | Val Loss=0.3664
# Epoch [5/25] Train Loss=0.1247 | Val Loss=0.3007
# Epoch [6/25] Train Loss=0.0780 | Val Loss=0.4698
# Epoch [7/25] Train Loss=0.0606 | Val Loss=0.5453
# Epoch [8/25] Train Loss=0.0220 | Val Loss=0.4237
# Epoch [9/25] Train Loss=0.0194 | Val Loss=0.6428
# Epoch [10/25] Train Loss=0.0272 | Val Loss=0.5869
# Epoch [11/25] Train Loss=0.0078 | Val Loss=0.6757
# Epoch [12/25] Train Loss=0.0098 | Val Loss=0.5809
# Epoch [13/25] Train Loss=0.0041 | Val Loss=0.4203
# Epoch [14/25] Train Loss=0.1052 | Val Loss=0.4554
# Epoch [15/25] Train Loss=0.1683 | Val Loss=0.4794
# Epoch [16/25] Train Loss=0.0602 | Val Loss=0.5771
# Epoch [17/25] Train Loss=0.0224 | Val Loss=0.6031
# Epoch [18/25] Train Loss=0.0134 | Val Loss=0.6206
# Epoch [19/25] Train Loss=0.0048 | Val Loss=0.7651
# Epoch [20/25] Train Loss=0.0027 | Val Loss=0.7673
# Epoch [21/25] Train Loss=0.0017 | Val Loss=0.8438
# Epoch [22/25] Train Loss=0.0024 | Val Loss=0.8529
# Epoch [23/25] Train Loss=0.0016 | Val Loss=0.8423
# Epoch [24/25] Train Loss=0.0035 | Val Loss=0.8224
# Epoch [25/25] Train Loss=0.0447 | Val Loss=0.7007
# ✅ Accuracy: 0.925 | Precision: 0.914 | Recall: 0.916 | F1: 0.915
# ⏱ Training Time: 108.15 min
# Confusion Matrix:
#  [[ 73   4   9]
#  [  0 134   0]
#  [ 14   0 124]]
# 🚀 Running CNN for Train-Test Split: 50:50
# Epoch [1/25] Train Loss=0.7988 | Val Loss=0.3264
# Epoch [2/25] Train Loss=0.3453 | Val Loss=0.2087
# Epoch [3/25] Train Loss=0.2569 | Val Loss=0.3774
# Epoch [4/25] Train Loss=0.2139 | Val Loss=0.0980
# Epoch [5/25] Train Loss=0.1881 | Val Loss=0.1045
# Epoch [6/25] Train Loss=0.1471 | Val Loss=0.0744
# Epoch [7/25] Train Loss=0.1549 | Val Loss=0.1111
# Epoch [8/25] Train Loss=0.0869 | Val Loss=0.0790
# Epoch [9/25] Train Loss=0.0592 | Val Loss=0.0518
# Epoch [10/25] Train Loss=0.0476 | Val Loss=0.0612
# Epoch [11/25] Train Loss=0.0127 | Val Loss=0.0957
# Epoch [12/25] Train Loss=0.0325 | Val Loss=0.1372
# Epoch [13/25] Train Loss=0.0070 | Val Loss=0.0434
# Epoch [14/25] Train Loss=0.0137 | Val Loss=0.0707
# Epoch [15/25] Train Loss=0.0118 | Val Loss=0.0513
# Epoch [16/25] Train Loss=0.0041 | Val Loss=0.2000
# Epoch [17/25] Train Loss=0.0024 | Val Loss=0.0389
# Epoch [18/25] Train Loss=0.0018 | Val Loss=0.0198
# Epoch [19/25] Train Loss=0.0009 | Val Loss=0.0247
# Epoch [20/25] Train Loss=0.0009 | Val Loss=0.0258
# Epoch [21/25] Train Loss=0.0003 | Val Loss=0.0265
# Epoch [22/25] Train Loss=0.0009 | Val Loss=0.0295
# Epoch [23/25] Train Loss=0.0006 | Val Loss=0.0362
# Epoch [24/25] Train Loss=0.0002 | Val Loss=0.0315
# Epoch [25/25] Train Loss=0.0003 | Val Loss=0.0324
# ✅ Accuracy: 0.908 | Precision: 0.907 | Recall: 0.888 | F1: 0.894
# ⏱ Training Time: 89.06 min
# Confusion Matrix:
#  [[ 80   8  23]
#  [  1 160   0]
#  [  9   0 166]]
# 🚀 Running CNN for Train-Test Split: 40:60
# Epoch [1/25] Train Loss=0.9592 | Val Loss=0.3396
# Epoch [2/25] Train Loss=0.3612 | Val Loss=0.3611
# Epoch [3/25] Train Loss=0.2729 | Val Loss=0.3630
# Epoch [4/25] Train Loss=0.2435 | Val Loss=0.2060
# Epoch [5/25] Train Loss=0.1926 | Val Loss=0.3748
# Epoch [6/25] Train Loss=0.2072 | Val Loss=0.1788
# Epoch [7/25] Train Loss=0.1409 | Val Loss=0.2334
# Epoch [8/25] Train Loss=0.1184 | Val Loss=0.2240
# Epoch [9/25] Train Loss=0.0701 | Val Loss=0.2510
# Epoch [10/25] Train Loss=0.0420 | Val Loss=0.2029
# Epoch [11/25] Train Loss=0.0295 | Val Loss=0.2154
# Epoch [12/25] Train Loss=0.0536 | Val Loss=0.1976
# Epoch [13/25] Train Loss=0.0306 | Val Loss=0.2866
# Epoch [14/25] Train Loss=0.0302 | Val Loss=0.3036
# Epoch [15/25] Train Loss=0.0175 | Val Loss=0.3607
# Epoch [16/25] Train Loss=0.0049 | Val Loss=0.2673
# Epoch [17/25] Train Loss=0.0239 | Val Loss=0.3299
# Epoch [18/25] Train Loss=0.0110 | Val Loss=0.4613
# Epoch [19/25] Train Loss=0.0216 | Val Loss=0.2195
# Epoch [20/25] Train Loss=0.0088 | Val Loss=0.2942
